# %% [markdown]
# # 37 - Collocation Sampling
#
# **Purpose**: Collocation point sampling strategies.
#
# This notebook demonstrates key functionality with synthetic data.

# %% [markdown]
# ## Installation (Kaggle/Colab)
#
# Run this cell to install the library if running on Kaggle or Google Colab.

# %%
# Uncomment the following line to install ununennium
# !pip install -q ununennium

# %% [markdown]
# ## Prerequisites and Environment Check

# %%
import sys
import torch
import numpy as np

print(f'Python: {sys.version}')
print(f'PyTorch: {torch.__version__}')
print(f'CUDA: {torch.cuda.is_available()}')

# %% [markdown]
# ## Reproducibility

# %%
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Core Workflow

# %%
import torch

# %%
# Collocation points
n_interior = 1000
n_boundary = 200
interior = torch.rand(n_interior, 2)  # Unit square
boundary = torch.cat([torch.zeros(50, 1), torch.rand(50, 1)], dim=1)  # Left edge sample
print(f'Interior: {n_interior}, Boundary: {n_boundary}')

# %% [markdown]
# ## Validation

# %%
# All cells executed successfully
print('Notebook validation passed')

# %% [markdown]
# ## Save Outputs

# %%
from pathlib import Path

ARTIFACT_DIR = Path('artifacts/notebooks/37')
ARTIFACT_DIR.mkdir(parents=True, exist_ok=True)
print(f'Artifacts directory: {ARTIFACT_DIR}')

# %% [markdown]
# ## Next Steps
#
# See the [notebooks README](README.md) for related tutorials.
