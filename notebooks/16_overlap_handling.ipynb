# %% [markdown]
# # 16 - Overlap Handling
#
# **Purpose**: Overlap-aware tiling and reconstruction.
#
# This notebook demonstrates key functionality with synthetic data.

# %% [markdown]
# ## Installation (Kaggle/Colab)
#
# Run this cell to install the library if running on Kaggle or Google Colab.

# %%
# Uncomment the following line to install ununennium
# !pip install -q ununennium

# %% [markdown]
# ## Prerequisites and Environment Check

# %%
import sys
import torch
import numpy as np

print(f'Python: {sys.version}')
print(f'PyTorch: {torch.__version__}')
print(f'CUDA: {torch.cuda.is_available()}')

# %% [markdown]
# ## Reproducibility

# %%
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Core Workflow

# %%
import torch

# %%
# Overlapping tiles
overlap = 32
image = torch.randn(4, 512, 512)
stride = 256 - overlap
n_tiles = ((512 - 256) // stride + 1) ** 2
print(f'Tiles with {overlap}px overlap: {n_tiles}')

# %% [markdown]
# ## Validation

# %%
# All cells executed successfully
print('Notebook validation passed')

# %% [markdown]
# ## Save Outputs

# %%
from pathlib import Path

ARTIFACT_DIR = Path('artifacts/notebooks/16')
ARTIFACT_DIR.mkdir(parents=True, exist_ok=True)
print(f'Artifacts directory: {ARTIFACT_DIR}')

# %% [markdown]
# ## Next Steps
#
# See the [notebooks README](README.md) for related tutorials.
