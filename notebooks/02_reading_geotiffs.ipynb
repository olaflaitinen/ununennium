# %% [markdown]
# # 02 - Reading GeoTIFFs
#
# **Purpose**: COG and GeoTIFF I/O with synthetic data.
#
# This notebook demonstrates key functionality with synthetic data.

# %% [markdown]
# ## Installation (Kaggle/Colab)
#
# Run this cell to install the library if running on Kaggle or Google Colab.

# %%
# Uncomment the following line to install ununennium
# !pip install -q ununennium

# %% [markdown]
# ## Prerequisites and Environment Check

# %%
import sys
import torch
import numpy as np

print(f'Python: {sys.version}')
print(f'PyTorch: {torch.__version__}')
print(f'CUDA: {torch.cuda.is_available()}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import sys
# ----> 2 import torch
#       3 import numpy as np
#       5 print(f'Python: {sys.version}')
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## Reproducibility

# %%
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Core Workflow

# %%
import torch
from ununennium.core import GeoTensor

# %%
# Synthetic GeoTIFF-like data
data = torch.randn(4, 1024, 1024)
gt = GeoTensor(data=data, crs='EPSG:4326')
print(f'Created synthetic raster: {gt.shape}')

# %% [markdown]
# ## Validation

# %%
# All cells executed successfully
print('Notebook validation passed')

# %% [markdown]
# ## Save Outputs

# %%
from pathlib import Path

ARTIFACT_DIR = Path('artifacts/notebooks/02')
ARTIFACT_DIR.mkdir(parents=True, exist_ok=True)
print(f'Artifacts directory: {ARTIFACT_DIR}')

# %% [markdown]
# ## Next Steps
#
# See the [notebooks README](README.md) for related tutorials.
